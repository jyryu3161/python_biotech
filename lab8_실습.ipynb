# %% [markdown]
# <a href="https://colab.research.google.com/github/jyryu3161/python_biotech/blob/main/lab8_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 실습

# %% [markdown]
# 단백질 서열 정보가 있는 fasta 파일을 읽어서 딕셔너리 자료형의 key는 단백질 정보, value는 단백질 서열이 들어가도록 만들어라.

# %% [markdown]
# ![download.png](data:image/png;base64,...)
